# %% [markdown]
#     # Remaining Useful life prediction of Lithium-ion in Electric vehicle Battery Mangement System

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install pickle
# Out:
# WARNING: Ignoring invalid distribution -ygments (c:\users\umsup\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\umsup\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# WARNING: Ignoring invalid distribution -ygments (c:\users\umsup\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\umsup\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\umsup\anaconda3\lib\site-packages)

# %%
import pickle as pkl
import pandas as pd
with open(r"C:\Users\umsup\OneDrive - Datapact Services Private Limited\Desktop\capstone project\FOUNDATION,METHODS  AND MODELS\summary_df.pkl", "rb") as f:
    object = pkl.load(f)
    
df = pd.DataFrame(object)
df.to_csv(r'file.csv')

# %%
print("df shape:",df.shape)
df.head(2)
# Out:
# df shape: (38811, 13)
#          IR        QC        QD    Tavg     Tmin      Tmax  chargetime  cycle  \
# 0  0.000000  0.000000  0.000000   0.000   0.0000   0.00000     0.00000    1.0
# 1  0.016739  1.071289  1.070312  31.875  29.5625  35.65625    13.34375    2.0
#
#    cell  cycle_life   C1   C2  Q1
# 0  b1c0        1190  3.6  3.6  80
# 1  b1c0        1190  3.6  3.6  80

# %%
import pickle as pkl
import pandas as pd
with open(r"C:\Users\umsup\OneDrive - Datapact Services Private Limited\Desktop\capstone project\FOUNDATION,METHODS  AND MODELS\summary_df_test.pkl", "rb") as f:
    object = pkl.load(f)
    
df1 = pd.DataFrame(object)
df1.to_csv(r'file_df_test.csv')

# %%
print("df1 shape:",df1.shape)
df1.head(2)
# Out:
# df1 shape: (24920, 13)
#          IR        QC        QD       Tavg       Tmin       Tmax  chargetime  \
# 0  0.017548  1.067383  1.068359  30.359375  29.000000  31.484375   10.335938
# 1  0.017502  1.069336  1.070312  29.156250  26.734375  31.656250   10.179688
#
#    cycle  cell  cycle_life   C1   C2  Q1
# 0    1.0  b1c0         300  1.0  6.0   4
# 1    2.0  b1c0         300  1.0  6.0   4

# %%
import pickle as pkl
import pandas as pd
with open(r"C:\Users\umsup\OneDrive - Datapact Services Private Limited\Desktop\capstone project\FOUNDATION,METHODS  AND MODELS\summary_df_test_2.pkl", "rb") as f:
    object = pkl.load(f)
    
df2 = pd.DataFrame(object)
df2.to_csv(r'file_df_test_2.csv')

# %%
print("df2 shape:",df2.shape)
df2.head(2)
# Out:
# df2 shape: (46581, 13)
#          IR        QC        QD      Tavg       Tmin      Tmax  chargetime  \
# 0  0.015434  1.066406  1.066406  32.15625  30.828125  33.43750   10.046875
# 1  0.015396  1.067383  1.067383  32.09375  30.781250  33.40625   10.046875
#
#    cycle  cell  cycle_life   C1   C2  Q1
# 0    1.0  b1c0        1009  5.0  4.0  67
# 1    2.0  b1c0        1009  5.0  4.0  67

# %%
data1=pd.concat([df,df1,df2])

# %%
data1['cycle'].nunique()
# Out:
# 1934

# %%
print("concat data shape:",data1.shape)
data1.head(),data1.tail()
# Out:
# concat data shape: (110312, 13)
# (         IR        QC        QD       Tavg       Tmin      Tmax  chargetime  \
#  0  0.000000  0.000000  0.000000   0.000000   0.000000   0.00000    0.000000
#  1  0.016739  1.071289  1.070312  31.875000  29.562500  35.65625   13.343750
#  2  0.016724  1.071289  1.072266  31.937500  29.609375  35.68750   13.421875
#  3  0.016678  1.072266  1.072266  31.937500  29.750000  35.68750   13.421875
#  4  0.016663  1.073242  1.073242  31.953125  29.640625  35.71875   13.343750
#
#     cycle  cell  cycle_life   C1   C2  Q1
#  0    1.0  b1c0        1190  3.6  3.6  80
#  1    2.0  b1c0        1190  3.6  3.6  80
#  2    3.0  b1c0        1190  3.6  3.6  80
#  3    4.0  b1c0        1190  3.6  3.6  80
#  4    5.0  b1c0        1190  3.6  3.6  80  ,
#              IR        QC        QD      Tavg       Tmin      Tmax  chargetime  \
#  1795  0.017532  0.881836  0.881348  32.53125  30.328125  34.56250   15.406250
# ...

# %%
data1.shape
# Out:
# (110312, 13)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110312 entries, 0 to 1799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IR          110312 non-null  float16
#  1   QC          110312 non-null  float16
#  2   QD          110312 non-null  float16
#  3   Tavg        110312 non-null  float16
#  4   Tmin        110312 non-null  float16
#  5   Tmax        110312 non-null  float16
#  6   chargetime  110312 non-null  float16
#  7   cycle       110312 non-null  float64
#  8   cell        110312 non-null  object
#  9   cycle_life  110312 non-null  int16
#  10  C1          110312 non-null  float64
#  11  C2          110312 non-null  float64
#  12  Q1          110312 non-null  int64
# dtypes: float16(7), float64(3), int16(1), int64(1), object(1)
# memory usage: 6.7+ MB

# %% [raw]
# #ir -internal resistance of the battery
# How does internal resistance affect battery performance?
#
# Internal Resistance – The resistance within the battery, generally different for charging and discharging, also dependent on the battery state of charge. As internal resistance increases, the battery efficiency decreases and thermal stability is reduced as more of the charging energy is converted into heat
# #qc-quick charge
# #qd-quick discharge
# #Tavg-temperature avg
# #Tmin-temperature min
# #Tmax-temperature max
# #chargetime
# #cycle-no. of cycle
# #cell-cell
# #cycle_life-target variable to be predict-charging/discharging rate
# #C1-capacityrate-1 hour=100ah
# #c2-capacity rate-0.5 ah
# #Q1-Q – Battery capacity(soc), measured in amp-hours.

# %% [markdown]
# # univariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.countplot(data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle_life', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
plt.hist(data1['cycle_life'])
# Out:
# (array([  704., 16334., 11778., 23603., 22516., 18827.,  7703.,     0.,
#          3278.,  5569.]),
#  array([ 148. ,  326.7,  505.4,  684.1,  862.8, 1041.5, 1220.2, 1398.9,
#         1577.6, 1756.3, 1935. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cycle_life', ylabel='Density'>

# %%
# it is also normally distributed , beacause it reaches many peaks and somewhat it looks like a bell shaped curve.

# %%
sns.distplot(data1['Q1'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Q1', ylabel='Density'>

# %%
sns.distplot(data1['chargetime'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='chargetime', ylabel='Density'>

# %%
sns.distplot(data1['C1'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='C1', ylabel='Density'>

# %%
#C1 is also normally distributed and it reach the peak at 4.8 ah

# %%
sns.distplot(data1['C2'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='C2', ylabel='Density'>

# %%
sns.distplot(data1['Tavg'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tavg', ylabel='Density'>

# %%
# temperature avg comes under 30-40 degree and normally distributed

# %%
sns.distplot(data1['QD'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='QD', ylabel='Density'>

# %%
sns.distplot(data1['cycle'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cycle', ylabel='Density'>

# %% [markdown]
# # Bivariate analysis

# %%
plt.figure(figsize=(10,10))
sns.pointplot(data1['Q1'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Q1', ylabel='cycle_life'>

# %%
#Q1 vs cycle life upward trend life cyle increases ,Q1 is the indicator for us.

# %%
plt.figure(figsize=(10,10))
sns.pointplot(data1['C1'],data1['Q1'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='C1', ylabel='Q1'>

# %%
# c1 increases at 4.8 at the maximum range of 80% Q1,it says the voltage reaches at the maximum range of Q1.

# %%
plt.figure(figsize=(20,20))
sns.pointplot(data1['cycle'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle', ylabel='cycle_life'>

# %%
#here we can understand no. of Cycle increases cycle life too increases

# %%
plt.figure(figsize=(10,10))
sns.pointplot(data1['QD'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='QD', ylabel='cycle_life'>

# %% [raw]
# sns.lineplot(data1['cycle'],data1['QD'],color='darkorange')

# %%
sns.barplot(data1['cycle'],data1['QD'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle', ylabel='QD'>

# %%
sns.barplot(data1['cycle'],data1['Q1'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle', ylabel='Q1'>

# %%
sns.barplot(data1['cycle'],data1['Tavg'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle', ylabel='Tavg'>

# %%
sns.barplot(data1['Tavg'],data1['cycle'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tavg', ylabel='cycle'>

# %%
sns.regplot(data1['QD'],data1['cycle_life'],color='darkorange')
# Out:
# <AxesSubplot:xlabel='QD', ylabel='cycle_life'>

# %%
#QD is always at 1 ah here its not related with cycle life

# %%
data1['cycle_life'].nunique()
# Out:
# 127

# %%
sns.barplot(data1['cycle'],data1['C1'],hue=data1['cell'[0:5]])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle', ylabel='C1'>

# %%
sns.regplot(data1['Q1'],data1['cycle_life'],color='darkorange')
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Q1', ylabel='cycle_life'>

# %%
data1['cycle_life'].value_counts()
# Out:
# 1935    1934
# 1836    1835
# 1801    1800
# 876     1750
# 870     1738
#         ...
# 438      464
# 335      361
# 300      326
# 209      208
# 148      170
# Name: cycle_life, Length: 127, dtype: int64

# %% [markdown]
# # Exploratory data analysis-Preprocessing

# %%
data1['cycle']=data1['cycle'].astype(int)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110312 entries, 0 to 1799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IR          110312 non-null  float16
#  1   QC          110312 non-null  float16
#  2   QD          110312 non-null  float16
#  3   Tavg        110312 non-null  float16
#  4   Tmin        110312 non-null  float16
#  5   Tmax        110312 non-null  float16
#  6   chargetime  110312 non-null  float16
#  7   cycle       110312 non-null  int32
#  8   cell        110312 non-null  object
#  9   cycle_life  110312 non-null  int16
#  10  C1          110312 non-null  float64
#  11  C2          110312 non-null  float64
#  12  Q1          110312 non-null  int64
# dtypes: float16(7), float64(2), int16(1), int32(1), int64(1), object(1)
# memory usage: 6.3+ MB

# %%
data1=data1[data1['IR']!=0]#removing all the zero values in the IR column

# %%
data1.shape
# Out:
# (110244, 13)

# %%
#we can take the first 100 cycle for cycle life prediction

# %%
data1 = data1[data1['cycle'] <= 100]

# %%
data1['cycle_life'].nunique()
# Out:
# 127

# %%
#missing values

# %%
data1['cycle_life'].isnull().sum()
# Out:
# 0

# %%
data1.isnull().sum()
# Out:
# IR            0
# QC            0
# QD            0
# Tavg          0
# Tmin          0
# Tmax          0
# chargetime    0
# cycle         0
# cell          0
# cycle_life    0
# C1            0
# C2            0
# Q1            0
# dtype: int64

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
# there is no missing values and Duplicates

# %%
data1.head()
# Out:
#          IR        QC        QD       Tavg       Tmin      Tmax  chargetime  \
# 1  0.016739  1.071289  1.070312  31.875000  29.562500  35.65625   13.343750
# 2  0.016724  1.071289  1.072266  31.937500  29.609375  35.68750   13.421875
# 3  0.016678  1.072266  1.072266  31.937500  29.750000  35.68750   13.421875
# 4  0.016663  1.073242  1.073242  31.953125  29.640625  35.71875   13.343750
# 5  0.016617  1.073242  1.073242  31.968750  29.750000  35.71875   13.343750
#
#    cycle  cell  cycle_life   C1   C2  Q1
# 1      2  b1c0        1190  3.6  3.6  80
# 2      3  b1c0        1190  3.6  3.6  80
# 3      4  b1c0        1190  3.6  3.6  80
# 4      5  b1c0        1190  3.6  3.6  80
# 5      6  b1c0        1190  3.6  3.6  80

# %%
data1.tail()
# Out:
#           IR        QC        QD      Tavg       Tmin      Tmax  chargetime  \
# 95  0.015671  1.071289  1.071289  32.71875  30.890625  34.71875   11.039062
# 96  0.015656  1.071289  1.071289  32.71875  30.765625  34.78125   11.039062
# 97  0.015656  1.071289  1.071289  32.71875  30.734375  34.78125   11.039062
# 98  0.015656  1.071289  1.071289  32.71875  30.718750  34.84375   11.039062
# 99  0.015656  1.071289  1.071289  32.71875  30.671875  34.81250   11.039062
#
#     cycle   cell  cycle_life   C1   C2  Q1
# 95     96  b1c45        1801  4.8  4.8  80
# 96     97  b1c45        1801  4.8  4.8  80
# 97     98  b1c45        1801  4.8  4.8  80
# 98     99  b1c45        1801  4.8  4.8  80
# 99    100  b1c45        1801  4.8  4.8  80

# %%
data1.shape
# Out:
# (13743, 13)

# %%
# now the shape become 13743 rows and 13 columns

# %%
#Statistical analysis

# %%
data1.describe()
# Out:
#                  IR            QC            QD          Tavg          Tmin  \
# count  13743.000000  13743.000000  13743.000000  1.374300e+04  1.374300e+04
# mean       0.016434      1.072266      1.071289           inf           inf
# std        0.001036      0.035522      0.023987  1.326172e+00  9.350586e-01
# min        0.012436      0.926270      0.925781  2.901562e+01  2.673438e+01
# 25%        0.015587      1.066406      1.067383  3.221875e+01  2.989062e+01
# 50%        0.016586      1.074219      1.074219  3.303125e+01  3.034375e+01
# 75%        0.017090      1.081055      1.081055  3.365625e+01  3.101562e+01
# max        0.020370      2.966797      2.884766  3.759375e+01  3.312500e+01
#
#                Tmax    chargetime         cycle    cycle_life            C1  \
# count  1.374300e+04  1.374300e+04  13743.000000  13743.000000  13743.000000
# mean            inf           inf     50.696136    791.237648      5.039133
# ...

# %%
#Here most of the mean and median nearly same values so mean= median=mode ,ie)most of the variables are normally distributed

# %%
#univariate analysis for first 100 cycle

# %%
sns.countplot(x=data1.cycle_life,data=data1)
# Out:
# <AxesSubplot:xlabel='cycle_life', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.pointplot(data1['Q1'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Q1', ylabel='cycle_life'>

# %%
plt.figure(figsize=(8,5))
sns.regplot(data1['QD'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='QD', ylabel='cycle_life'>

# %% [raw]
# rgb = []
# for j in data1['cycle_life']:
#     j = j * 0.5
#     c = [j * 255 / 255, j * 254 /255 , j* 253/ 255]
#     rgb.append(c)

# %%
plt.figure(figsize=(30,15))
plt.scatter(data1['QD'],data1['cycle_life'],c='red')

# %%
#discharge points vs  All the discharge points are

# %%
plt.figure(figsize=(8,5))
sns.regplot(data1['QC'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='QC', ylabel='cycle_life'>

# %%
sns.pointplot(data1['cell'],data1['cycle_life'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cell', ylabel='cycle_life'>

# %%
sns.barplot(data1['C1'],data1["Q1"])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='C1', ylabel='Q1'>

# %%
sns.barplot(data1['C2'],data1["Q1"])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='C2', ylabel='Q1'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(data1['Q1'],data1["Tavg"])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Q1', ylabel='Tavg'>

# %%
sns.distplot(data1['cycle_life'])
# Out:
# <AxesSubplot:xlabel='cycle_life', ylabel='Density'>

# %%
sns.barplot(data1['cycle_life'],data1['Q1'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cycle_life', ylabel='Q1'>

# %%
data1['cell'].max()
# Out:
# 'b1c9'

# %%
data1['cell'].min()
# Out:
# 'b1c0'

# %%
data1['cell'].value_counts().sort_values()
# Out:
# b1c47    100
# b1c46    100
# b1c23    199
# b1c32    199
# b1c16    298
# b1c1     298
# b1c11    298
# b1c10    298
# b1c2     298
# b1c7     298
# b1c6     298
# b1c21    298
# b1c4     298
# b1c20    298
# b1c3     298
# b1c15    299
# b1c19    299
# b1c18    299
# b1c17    299
# b1c14    299
# b1c13    299
# b1c9     299
# b1c8     299
# b1c5     299
# b1c0     299
# b1c25    299
# b1c22    299
# b1c26    299
# b1c27    299
# b1c28    299
# b1c29    299
# b1c30    299
# b1c31    299
# b1c33    299
# b1c34    299
# b1c24    299
# b1c35    299
# b1c37    299
# b1c38    299
# b1c39    299
# b1c40    299
# b1c41    299
# b1c42    299
# b1c43    299
# b1c44    299
# b1c45    299
# b1c36    299
# b1c12    299
# Name: cell, dtype: int64

# %%
data1['cell'].nunique()
# Out:
# 48

# %% [markdown]
# # Multivariate analysis

# %%
import seaborn as sns

# %%
correlations = data1.corr()
plt.figure(figsize=(16, 12))
ax = sns.heatmap(correlations, square=True, annot=True,
                 fmt='.2f', linecolor='white', cmap="vlag")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30, fontsize=12)
plt.title("Correlation heatmap", fontsize=20)
plt.show()

# %% [raw]
# #here some of the variable are highly correlated,inside the temperature all are correlated positively,
# cycle_life is positively correlated with QC,QD,Tavg,Tmin,chargetime,C1 and Q1
# and negatively correlated on IR,Tmax,C2,so here most of the variables related to each other

# %% [markdown]
# # null hypothesis:The given data is not significant for first 100 cycles
# alternative hypothesis:The given data is significant for first 100 cycles

# %%
from sklearn.model_selection import train_test_split

# %%
x = data1.drop(['cell','cycle','cycle_life'], axis = 1)
y = data1[['cycle_life']]
x.shape,y.shape
# Out:
# ((13743, 10), (13743, 1))

# %%
#train and test split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=1,shuffle=True)

# %%
print('X_train_shape: ', xtrain.shape)
print('y_train_shape: ', ytrain.shape)
print('X_test_shape: ', xtest.shape)
print('y_test_shape: ', ytest.shape)
# Out:
# X_train_shape:  (9620, 10)
# y_train_shape:  (9620, 1)
# X_test_shape:  (4123, 10)
# y_test_shape:  (4123, 1)

# %%
df_result = pd.DataFrame()
df_result['ytest'] = ytest

# %%
from sklearn.linear_model import LinearRegression
reg_lin = LinearRegression(normalize=True)
reg_lin.fit(xtrain, ytrain)
df_result['ypred'] = reg_lin.predict(xtest)
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())

# %%
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)
ytest.shape,ypred.shape
# Out:
# ((4123, 1), (4123, 1))

# %%
r2_score(ytest,ypred)
# Out:
# 0.5414781561577606

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# %%
print('R2 error: ',r2_score(ytest,ypred))
print('RMSE:',np.sqrt(mean_squared_error(ytest,ypred)))
print('MAE:', mean_absolute_error(ytest,ypred))
# Out:
# R2 error:  0.5414781561577606
# RMSE: 218.74098474355978
# MAE: 159.22206093787017

# %%
print('R2 error: ',r2_score(df_result['ytest'], df_result['ypred']))
print('RMSE',np.sqrt(mean_squared_error(df_result['ytest'], df_result['ypred'])))
print('MAE', mean_absolute_error(df_result['ytest'], df_result['ypred']))
# Out:
# R2 error:  0.5414781561577606
# RMSE 218.74098474355975
# MAE 159.22206093787022

# %% [raw]
# #here the r2 score is 50%

# %%
sum((abs(df_result['ytest'] - df_result['ypred']))/df_result['ytest'])/len(df_result['ypred'])*100
# Out:
# 22.737551534156704

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,4))
sns.regplot(df_result['ytest'], df_result['ypred'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ytest', ylabel='ypred'>

# %%
from sklearn.ensemble import RandomForestRegressor
Forestmod = RandomForestRegressor(n_estimators=500, random_state=0)
Forestmod.fit(xtrain, ytrain)
df_result['ypred1'] = Forestmod.predict(xtest)
# Out:
# C:\Users\umsup\AppData\Local\Temp\ipykernel_15324\3252978449.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Forestmod.fit(xtrain, ytrain)

# %%
print('R2 error: ',r2_score(df_result['ytest'], df_result['ypred1']))
print('RMSE',np.sqrt(mean_squared_error(df_result['ytest'], df_result['ypred1'])))
print('MAE', mean_absolute_error(df_result['ytest'], df_result['ypred1']))
# Out:
# R2 error:  0.9968522109824104
# RMSE 18.123954188467287
# MAE 2.2454557361144794

# %%
#here the r2=0.99,so perfectly predict the life cycle,it is significant

# %%
plt.figure(figsize=(10,6))
sns.regplot(df_result['ytest'], df_result['ypred1'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ytest', ylabel='ypred1'>

# %%
data1.nunique()
# Out:
# IR            475
# QC            226
# QD            192
# Tavg          360
# Tmin          347
# Tmax          432
# chargetime    242
# cycle         100
# cell           48
# cycle_life    127
# C1             19
# C2             18
# Q1             38
# dtype: int64

# %%
data1.C1.value_counts()
# Out:
# 5.60    2200
# 6.00    1788
# 5.40    1381
# 4.80    1096
# 5.30     800
# 5.00     700
# 3.60     695
# 5.20     600
# 0.00     600
# 7.00     594
# 8.00     594
# 4.40     499
# 4.00     496
# 5.90     400
# 4.90     300
# 4.65     300
# 3.70     300
# 2.00     300
# 1.00     100
# Name: C1, dtype: int64

# %% [markdown]
# # classification

# %%
data2=pd.concat([df,df1,df2])

# %%
sns.countplot(x=data2.cycle_life,data=data2)
# Out:
# <AxesSubplot:xlabel='cycle_life', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
data2.boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
data2.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.drop('cycle_life', axis = 1).hist()

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()  

# print the skewness for each numeric independent variable
print('Skewness:')
# we drop the target variable using drop()
# 'axis=1' drops the specified column
# skew() returns the coefficient of skewness for each variable
data.drop('cycle_life', axis = 1).skew()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11428\3014251461.py in <module>
# ----> 1 data.drop('cycle_life', axis = 1).hist()
#       2
#       3 # adjust the subplots
#       4 plt.tight_layout()
#       5
#
# NameError: name 'data' is not defined

# %%
data2.drop('cycle_life', axis = 1).hist()

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()  

# print the skewness for each numeric independent variable
print('Skewness:')
# we drop the target variable using drop()
# 'axis=1' drops the specified column
# skew() returns the coefficient of skewness for each variable
data2.drop('cycle_life', axis = 1).skew()
# Out:
# Skewness:
# C:\Users\umsup\anaconda3\lib\site-packages\pandas\core\nanops.py:1206: RuntimeWarning: overflow encountered in multiply
#   adjusted3 = adjusted2 * adjusted
# C:\Users\umsup\anaconda3\lib\site-packages\pandas\core\nanops.py:1205: RuntimeWarning: overflow encountered in square
#   adjusted2 = adjusted**2
# C:\Users\umsup\AppData\Local\Temp\ipykernel_11428\4236938555.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2.drop('cycle_life', axis = 1).skew()
# IR                 NaN
# QC                 NaN
# QD                 NaN
# Tavg               NaN
# Tmin               NaN
# Tmax               NaN
# chargetime         NaN
# cycle         1.023032
# C1           -1.563123
# C2            0.422305
# Q1           -0.175691
# dtype: float64

# %%
plt.figure(figsize=(30,10))
sns.countplot(data2.cell)

# add plot and axes labels
# set text size using 'fontsize'
plt.title('Count Plot for Categorical Variable (cell)', fontsize = 15)
plt.xlabel('cell', fontsize = 15)
plt.ylabel('Count', fontsize = 15)

# display the plot
plt.show()
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#classification

# %%
#data2=pd.concat([df,df1,df2])

# %%
data2 = data2[data2['cycle'] <= 20]

# %%
data2['class'] = np.where(data2['cycle_life'] >= 700, 1, 0)
data2
# Out:
#           IR        QC        QD       Tavg       Tmin      Tmax  chargetime  \
# 0   0.000000  0.000000  0.000000   0.000000   0.000000   0.00000    0.000000
# 1   0.016739  1.071289  1.070312  31.875000  29.562500  35.65625   13.343750
# 2   0.016724  1.071289  1.072266  31.937500  29.609375  35.68750   13.421875
# 3   0.016678  1.072266  1.072266  31.937500  29.750000  35.68750   13.421875
# 4   0.016663  1.073242  1.073242  31.953125  29.640625  35.71875   13.343750
# ..       ...       ...       ...        ...        ...       ...         ...
# 15  0.015602  1.071289  1.071289  32.656250  30.781250  34.53125   11.039062
# 16  0.015602  1.071289  1.071289  32.656250  30.843750  34.50000   11.039062
# 17  0.015594  1.071289  1.071289  32.656250  30.828125  34.50000   11.039062
# 18  0.015594  1.071289  1.071289  32.593750  30.781250  34.37500   11.039062
# 19  0.015602  1.071289  1.071289  32.656250  30.875000  34.59375   11.039062
#
# ...

# %%
data2.head(),data2.tail()
# Out:
# (         IR        QC        QD       Tavg       Tmin      Tmax  chargetime  \
#  0  0.000000  0.000000  0.000000   0.000000   0.000000   0.00000    0.000000
#  1  0.016739  1.071289  1.070312  31.875000  29.562500  35.65625   13.343750
#  2  0.016724  1.071289  1.072266  31.937500  29.609375  35.68750   13.421875
#  3  0.016678  1.072266  1.072266  31.937500  29.750000  35.68750   13.421875
#  4  0.016663  1.073242  1.073242  31.953125  29.640625  35.71875   13.343750
#
#     cycle  cell  cycle_life   C1   C2  Q1  class
#  0    1.0  b1c0        1190  3.6  3.6  80      1
#  1    2.0  b1c0        1190  3.6  3.6  80      1
#  2    3.0  b1c0        1190  3.6  3.6  80      1
#  3    4.0  b1c0        1190  3.6  3.6  80      1
#  4    5.0  b1c0        1190  3.6  3.6  80      1  ,
#            IR        QC        QD      Tavg       Tmin      Tmax  chargetime  \
#  15  0.015602  1.071289  1.071289  32.65625  30.781250  34.53125   11.039062
# ...

# %%
data2.shape
# Out:
# (2760, 14)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2760 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IR          2760 non-null   float16
#  1   QC          2760 non-null   float16
#  2   QD          2760 non-null   float16
#  3   Tavg        2760 non-null   float16
#  4   Tmin        2760 non-null   float16
#  5   Tmax        2760 non-null   float16
#  6   chargetime  2760 non-null   float16
#  7   cycle       2760 non-null   float64
#  8   cell        2760 non-null   object
#  9   cycle_life  2760 non-null   int16
#  10  C1          2760 non-null   float64
#  11  C2          2760 non-null   float64
#  12  Q1          2760 non-null   int64
#  13  class       2760 non-null   int32
# dtypes: float16(7), float64(3), int16(1), int32(1), int64(1), object(1)
# memory usage: 183.3+ KB

# %%
data2.describe()
# Out:
#                 IR           QC           QD         Tavg         Tmin  \
# count  2760.000000  2760.000000  2760.000000  2760.000000  2760.000000
# mean      0.016129     1.054688     1.053711          inf          inf
# std       0.002573     0.139404     0.138428     4.394531     3.990234
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.015572     1.067139     1.067383    32.125000    29.906250
# 50%       0.016571     1.073242     1.073242    32.906250    30.359375
# 75%       0.017166     1.080078     1.081055    33.468750    30.843750
# max       0.020370     1.546875     1.539062    37.093750    33.125000
#
#               Tmax   chargetime        cycle   cycle_life           C1  \
# count  2760.000000  2760.000000  2760.000000  2760.000000  2760.000000
# mean           inf    10.804688    10.500000   791.507246     5.041667
# std       4.925781          inf     5.767326   321.156059     1.545605
# ...

# %%
data2.isnull().sum()
# Out:
# IR            0
# QC            0
# QD            0
# Tavg          0
# Tmin          0
# Tmax          0
# chargetime    0
# cycle         0
# cell          0
# cycle_life    0
# C1            0
# C2            0
# Q1            0
# class         0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
data2.boxplot()
# Out:
# <AxesSubplot:>

# %%
data2['class'].value_counts()
# Out:
# 1    1620
# 0    1140
# Name: class, dtype: int64

# %%
df_target = data2['class'].copy()

# get counts of 0's and 1's 
df_target.value_counts()

# plot the countplot of the variable 'Class'
sns.countplot(x = df_target)

# use below code to print the values in the graph
# 'x' and 'y' gives position of the text
# 's' is the text 
plt.text(x = -0.05, y = df_target.value_counts()[0] + 1, s = str(round((df_target.value_counts()[0])*100/len(df_target),2)) + '%')
plt.text(x = 0.95, y = df_target.value_counts()[1] +1, s = str(round((df_target.value_counts()[1])*100/len(df_target),2)) + '%')

# add plot and axes labels
# set text size using 'fontsize'
plt.title('Count Plot for Target Variable (Class)', fontsize = 15)
plt.xlabel('Target Variable', fontsize = 15)
plt.ylabel('Count', fontsize = 15)

# to show the plot
plt.show()

# %%
Q1 = data2.quantile(0.25)

# calculate the third quartile
Q3 = data2.quantile(0.75)

# The Interquartile Range (IQR) is defined as the difference between the third and first quartile
# calculate IQR for each numeric variable
IQR = Q3 - Q1

# retrieve the dataframe without the outliers
# '~' returns the values that do not satisfy the given conditions 
# i.e. it returns values between the range [Q1-1.5*IQR, Q3+1.5*IQR]
# '|' is used as 'OR' operator on multiple conditions   
# 'any(axis=1)' checks the entire row for atleast one 'True' entry (the rows represent outliers in the data)
data2 = data2[~((data2 < (Q1 - 1.5 * IQR)) | (data2 > (Q3 + 1.5 * IQR))).any(axis=1)]

# reset the index of the dataframe without outliers
data2 = data2.reset_index(drop = True)

# check the shape of the data
data2.shape
# Out:
# C:\Users\umsup\AppData\Local\Temp\ipykernel_11428\4227137495.py:15: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data2 = data2[~((data2 < (Q1 - 1.5 * IQR)) | (data2 > (Q3 + 1.5 * IQR))).any(axis=1)]
# (1854, 14)

# %%
data2['cycle_life'].value_counts()
# Out:
# 499     40
# 828     40
# 429     40
# 487     40
# 731     39
#         ..
# 1315    11
# 1227     9
# 495      2
# 1158     1
# 1028     1
# Name: cycle_life, Length: 92, dtype: int64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854 entries, 0 to 1853
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IR          1854 non-null   float16
#  1   QC          1854 non-null   float16
#  2   QD          1854 non-null   float16
#  3   Tavg        1854 non-null   float16
#  4   Tmin        1854 non-null   float16
#  5   Tmax        1854 non-null   float16
#  6   chargetime  1854 non-null   float16
#  7   cycle       1854 non-null   float64
#  8   cell        1854 non-null   object
#  9   cycle_life  1854 non-null   int16
#  10  C1          1854 non-null   float64
#  11  C2          1854 non-null   float64
#  12  Q1          1854 non-null   int64
#  13  class       1854 non-null   int32
# dtypes: float16(7), float64(3), int16(1), int32(1), int64(1), object(1)
# memory usage: 108.8+ KB

# %%
plt.figure(figsize=(10,10))
data2.boxplot()
# Out:
# <AxesSubplot:>

# %%
data2.drop('class', axis = 1).hist()

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()  

# print the skewness for each numeric independent variable
print('Skewness:')
# we drop the target variable using drop()
# 'axis=1' drops the specified column
# skew() returns the coefficient of skewness for each variable
data2.drop('class', axis = 1).skew()
# Out:
# Skewness:
# C:\Users\umsup\anaconda3\lib\site-packages\pandas\core\nanops.py:1218: RuntimeWarning: overflow encountered in multiply
#   result = (count * (count - 1) ** 0.5 / (count - 2)) * (m3 / m2**1.5)
# C:\Users\umsup\AppData\Local\Temp\ipykernel_11428\666580135.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2.drop('class', axis = 1).skew()
# IR                -inf
# QC                -inf
# QD                -inf
# Tavg               inf
# Tmin               inf
# Tmax              -inf
# chargetime         inf
# cycle        -0.002180
# cycle_life    0.819030
# C1           -0.859684
# C2            0.240106
# Q1           -0.218908
# dtype: float64

# %%
Q1 = data2.quantile(0.25)

# calculate the third quartile
Q3 = data2.quantile(0.75)

# The Interquartile Range (IQR) is defined as the difference between the third and first quartile
# calculate IQR for each numeric variable
IQR = Q3 - Q1

# retrieve the dataframe without the outliers
# '~' returns the values that do not satisfy the given conditions 
# i.e. it returns values between the range [Q1-1.5*IQR, Q3+1.5*IQR]
# '|' is used as 'OR' operator on multiple conditions   
# 'any(axis=1)' checks the entire row for atleast one 'True' entry (the rows represent outliers in the data)
data2 = data2[~((data2 < (Q1 - 1.5 * IQR)) | (data2 > (Q3 + 1.5 * IQR))).any(axis=1)]

# reset the index of the dataframe without outliers
data2= data2.reset_index(drop = True)

# check the shape of the data
data2.shape
# Out:
# C:\Users\umsup\AppData\Local\Temp\ipykernel_11428\422942740.py:15: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data2 = data2[~((data2 < (Q1 - 1.5 * IQR)) | (data2 > (Q3 + 1.5 * IQR))).any(axis=1)]
# (1333, 14)

# %%
X = data2.drop(['cycle_life','cell','cycle', 'class'], axis = 1)

# %%
y=data2['class']

# %%
print('X_shape: ', X.shape)
print('y_shape: ', y.shape)
# Out:
# X_shape:  (1333, 10)
# y_shape:  (1333,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, shuffle=True)

# %%
print('X_train_shape: ', X_train.shape)
print('y_train_shape: ', y_train.shape)

print('X_test_shape: ', X_test.shape)
print('y_test_shape: ', y_test.shape)
# Out:
# X_train_shape:  (933, 10)
# y_train_shape:  (933,)
# X_test_shape:  (400, 10)
# y_test_shape:  (400,)

# %%
df_result = pd.DataFrame()
df_result['y_test'] = y_test

# %%
#Logistic regression

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from sklearn.linear_model import LogisticRegression
logmod = LogisticRegression(random_state=0)
logreg=logmod.fit(X_train, y_train)
df_result['y_pred'] = logreg.predict(X_test)
#print(logreg.summary())
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
df_result.head()
# Out:
#       y_test  y_pred
# 1157       1       1
# 445        0       0
# 458        0       0
# 251        0       0
# 1253       1       1

# %%
print('Accuracy: ', accuracy_score(df_result['y_test'], df_result['y_pred']) )
# Out:
# Accuracy:  0.935

# %%
from sklearn import datasets,metrics

# %%
metrics.plot_roc_curve(logreg,X_test,df_result['y_test'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
tn, fp, fn, tp = confusion_matrix(df_result['y_test'], df_result['y_pred']).ravel()
print('True negative: ', tn)
print('false positive: ', fp)
print('false negative: ', fn)
print('True positive: ', tp)
# Out:
# True negative:  204
# false positive:  7
# false negative:  19
# True positive:  170

# %%
print('Confusion matrix \n', confusion_matrix(df_result['y_test'], df_result['y_pred']))
# Out:
# Confusion matrix
#  [[204   7]
#  [ 19 170]]

# %%
#random forest classification model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfmod = RandomForestClassifier(random_state=0)

# %%
rf=rfmod.fit(X_train, y_train)

# %%
df_result['y_pred5'] = rf.predict(X_test)

# %%
print('Accuracy: ', accuracy_score(df_result['y_test'], df_result['y_pred5']) )
# Out:
# Accuracy:  1.0

# %%
tn, fp, fn, tp = confusion_matrix(df_result['y_test'], df_result['y_pred']).ravel()
print('True negative: ', tn)
print('false positive: ', fp)
print('false negative: ', fn)
print('True positive: ', tp)
# Out:
# True negative:  204
# false positive:  7
# false negative:  19
# True positive:  170

# %%
confusion_matrix(df_result['y_test'], df_result['y_pred5'])
# Out:
# array([[211,   0],
#        [  0, 189]], dtype=int64)

# %%
metrics.plot_roc_curve(rf,X_test,df_result['y_test'])
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Support vector machine

# %%
from sklearn import svm

# %%
#clf=svm.SVC(kernel='linear')

# %%
#svmmod=clf(X_train,y_train)

# %%
#df_result(y_pred6)=svmmod.predict(X_test)

# %%
svc_classifier = svm.SVC(kernel='rbf', gamma ='auto',C=1.0).fit(X_train, y_train)
df_result['y_pred6']= svc_classifier.predict(X_test)

# %%
from sklearn import metrics

# %%
print("Accuracy:",metrics.accuracy_score(df_result['y_test'],df_result['y_pred6']))
# Out:
# Accuracy: 0.99

# %%
print("precision:",metrics.precision_score(df_result['y_test'],df_result['y_pred6']))
# Out:
# precision: 1.0

# %%
print("Recall:",metrics.recall_score(df_result['y_test'],df_result['y_pred6']))
# Out:
# Recall: 0.9788359788359788

# %%
print("F1score:",metrics.f1_score(df_result['y_test'],df_result['y_pred6']))
# Out:
# F1score: 0.9893048128342246

# %%
confusion_matrix(df_result['y_test'], df_result['y_pred6'])
# Out:
# array([[211,   0],
#        [  4, 185]], dtype=int64)

# %%
4/936
# Out:
# 0.004273504273504274

# %%
# 5 cycle

# %%
data3=pd.concat([df,df1,df2])

# %%
data3 = data3[data3['cycle'] <= 5]

# %%
data3.head()
# Out:
#          IR        QC        QD       Tavg       Tmin      Tmax  chargetime  \
# 0  0.000000  0.000000  0.000000   0.000000   0.000000   0.00000    0.000000
# 1  0.016739  1.071289  1.070312  31.875000  29.562500  35.65625   13.343750
# 2  0.016724  1.071289  1.072266  31.937500  29.609375  35.68750   13.421875
# 3  0.016678  1.072266  1.072266  31.937500  29.750000  35.68750   13.421875
# 4  0.016663  1.073242  1.073242  31.953125  29.640625  35.71875   13.343750
#
#    cycle  cell  cycle_life   C1   C2  Q1
# 0    1.0  b1c0        1190  3.6  3.6  80
# 1    2.0  b1c0        1190  3.6  3.6  80
# 2    3.0  b1c0        1190  3.6  3.6  80
# 3    4.0  b1c0        1190  3.6  3.6  80
# 4    5.0  b1c0        1190  3.6  3.6  80

# %%
data3['cycle'] = data3['cycle'].astype('int16')

# %%
data3 = data3[data3['IR'] != 0]

# %%
data3['class1'] = np.where(data3['cycle_life'] >= 700, 1, 0)

# %%
data3.shape
# Out:
# (644, 14)

# %%
df_target = data3['class1'].copy()

# get counts of 0's and 1's 
df_target.value_counts()

# plot the countplot of the variable 'Class1'
sns.countplot(x = df_target)

# use below code to print the values in the graph
# 'x' and 'y' gives position of the text
# 's' is the text 
plt.text(x = -0.05, y = df_target.value_counts()[0] + 1, s = str(round((df_target.value_counts()[0])*100/len(df_target),2)) + '%')
plt.text(x = 0.95, y = df_target.value_counts()[1] +1, s = str(round((df_target.value_counts()[1])*100/len(df_target),2)) + '%')

# add plot and axes labels
# set text size using 'fontsize'
plt.title('Count Plot for Target Variable (Class1)', fontsize = 15)
plt.xlabel('Target Variable', fontsize = 15)
plt.ylabel('Count', fontsize = 15)

# to show the plot
plt.show()

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 1 to 4
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IR          644 non-null    float16
#  1   QC          644 non-null    float16
#  2   QD          644 non-null    float16
#  3   Tavg        644 non-null    float16
#  4   Tmin        644 non-null    float16
#  5   Tmax        644 non-null    float16
#  6   chargetime  644 non-null    float16
#  7   cycle       644 non-null    int16
#  8   cell        644 non-null    object
#  9   cycle_life  644 non-null    int16
#  10  C1          644 non-null    float64
#  11  C2          644 non-null    float64
#  12  Q1          644 non-null    int64
#  13  class1      644 non-null    int32
# dtypes: float16(7), float64(2), int16(2), int32(1), int64(1), object(1)
# memory usage: 39.0+ KB

# %%
outlier

# %%
data3.drop('class1', axis = 1).hist()

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()  

# print the skewness for each numeric independent variable
print('Skewness:')
# we drop the target variable using drop()
# 'axis=1' drops the specified column
# skew() returns the coefficient of skewness for each variable
data3.drop('class1', axis = 1).skew()
# Out:
# Skewness:
# C:\Users\umsup\AppData\Local\Temp\ipykernel_15324\621371999.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data3.drop('class1', axis = 1).skew()
# IR           -0.066650
# QC           -2.734375
# QD           -2.822266
# Tavg          0.241821
# Tmin          0.017868
# Tmax         -0.697266
# chargetime    1.962891
# cycle        -0.088046
# cycle_life    0.978350
# C1           -1.494803
# C2            0.385583
# Q1           -0.082369
# dtype: float64

# %% [raw]
# some of the variables are positively skewed,some are negatively skwed,so we remove the outliers

# %%
def remove_outlier_IQR(data3):
    Q1=data3.quantile(0.25)
    Q3=data3.quantile(0.75)
    IQR=Q3-Q1
    df_final=data3[~((data3<(Q1-1.5*IQR)) | (data3>(Q3+1.5*IQR)))]
    return df_final

# %%
df_outlier_removed=remove_outlier_IQR(data3.chargetime)
df_outlier_removed=pd.DataFrame(df_outlier_removed)
ind_diff=data3.index.difference(df_outlier_removed.index)

for i in range(0, len(ind_diff),1):
    df_final=data3.drop([ind_diff[i]])
    data3=df_final
    
sns.boxplot(data=data3)
plt.xticks(rotation=90)
plt.ylabel('Cycle Life')
# Out:
# Text(0, 0.5, 'Cycle Life')

# %%
Q1 = data3.quantile(0.25)

# calculate the third quartile
Q3 = data3.quantile(0.75)

# The Interquartile Range (IQR) is defined as the difference between the third and first quartile
# calculate IQR for each numeric variable
IQR = Q3 - Q1

# retrieve the dataframe without the outliers
# '~' returns the values that do not satisfy the given conditions 
# i.e. it returns values between the range [Q1-1.5*IQR, Q3+1.5*IQR]
# '|' is used as 'OR' operator on multiple conditions   
# 'any(axis=1)' checks the entire row for atleast one 'True' entry (the rows represent outliers in the data)
data3 = data3[~((data3 < (Q1 - 1.5 * IQR)) | (data3 > (Q3 + 1.5 * IQR))).any(axis=1)]

# reset the index of the dataframe without outliers
data3 = data3.reset_index(drop = True)

# check the shape of the data
data3.shape
# Out:
# C:\Users\umsup\AppData\Local\Temp\ipykernel_15324\434164561.py:15: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3 = data3[~((data3 < (Q1 - 1.5 * IQR)) | (data3 > (Q3 + 1.5 * IQR))).any(axis=1)]
# (441, 14)

# %%
data3.boxplot()
# Out:
# <AxesSubplot:>

# %%
data3.drop('class1', axis = 1).hist()

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()  

# print the skewness for each numeric independent variable
print('Skewness:')
# we drop the target variable using drop()
# 'axis=1' drops the specified column
# skew() returns the coefficient of skewness for each variable
data3.drop('class1', axis = 1).skew()
# Out:
# Skewness:
# C:\Users\umsup\AppData\Local\Temp\ipykernel_15324\621371999.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data3.drop('class1', axis = 1).skew()
# IR           -0.283203
# QC           -0.211182
# QD           -0.244263
# Tavg          0.519531
# Tmin          0.461426
# Tmax         -0.268799
# chargetime    1.274414
# cycle        -0.099929
# cycle_life    0.874612
# C1           -0.890876
# C2            0.233109
# Q1           -0.197316
# dtype: float64

# %%
# after removing the outliers it looks better

# %%
data3.describe()
# Out:
#                IR          QC          QD        Tavg        Tmin        Tmax  \
# count  441.000000  441.000000  441.000000  441.000000  441.000000  441.000000
# mean     0.016556    1.071289    1.071289   33.093750   30.625000   36.281250
# std      0.001145    0.009224    0.009109    1.015625    0.752930    1.348633
# min      0.013168    1.047852    1.047852   30.843750   28.906250   32.843750
# 25%      0.015610    1.066406    1.066406   32.406250   30.046875   35.250000
# 50%      0.016663    1.070312    1.071289   33.000000   30.531250   36.468750
# 75%      0.017532    1.077148    1.077148   33.531250   31.046875   37.218750
# max      0.019882    1.094727    1.094727   35.500000   32.281250   39.656250
#
#        chargetime       cycle   cycle_life          C1          C2  \
# count  441.000000  441.000000   441.000000  441.000000  441.000000
# mean    10.250000    3.140590   752.800454    5.169955    4.293197
# ...

# %% [raw]
# #mean=meadian=mode,so most of the variables are normal

# %%
x3 = data3.drop(['cycle_life','cell','cycle', 'class1'], axis = 1)
y3=data3['class1']

# %%
x3.shape,y3.shape
# Out:
# ((441, 10), (441,))

# %%
x3train,x3test,y3train,y3test=train_test_split(x3,y3,test_size=0.3, random_state=0, shuffle=True)

# %%
x3train.shape,x3test.shape,y3train.shape,y3test.shape
# Out:
# ((308, 10), (133, 10), (308,), (133,))

# %%
df_result = pd.DataFrame()
df_result['y3test'] = y3test

# %%
from sklearn.linear_model import LogisticRegression
reg_log_5 = LogisticRegression(random_state=0)
reg_log_5.fit(x3train, y3train)
df_result['y3pred'] = reg_log_5.predict(x3test)
# Out:
# C:\Users\umsup\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print('Accuracy: ', accuracy_score(df_result['y3test'], df_result['y3pred']) )
# Out:
# Accuracy:  0.9699248120300752

# %%
tn, fp, fn, tp = confusion_matrix(df_result['y3test'], df_result['y3pred']).ravel()
print('True negative: ', tn)
print('false positive: ', fp)
print('false negative: ', fn)
print('True positive: ', tp)
# Out:
# True negative:  56
# false positive:  0
# false negative:  0
# True positive:  77

# %%
print('Confusion matrix \n', confusion_matrix(df_result['y3test'], df_result['y3pred']))
# Out:
# Confusion matrix
#  [[56  0]
#  [ 0 77]]

# %%
#all the values are true

# %%
Forest = RandomForestClassifier(random_state=0)

# %%
Forest.fit(x3train, y3train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
df_result['y3pred'] = Forest.predict(x3test)

# %%
print('Accuracy: ', accuracy_score(df_result['y3test'], df_result['y3pred']) )
# Out:
# Accuracy:  1.0

# %%
tn, fp, fn, tp = confusion_matrix(df_result['y3test'], df_result['y3pred']).ravel()
print('True negative: ', tn)
print('false positive: ', fp)
print('false negative: ', fn)
print('True positive: ', tp)
# Out:
# True negative:  56
# false positive:  0
# false negative:  0
# True positive:  77

# %%
print('Confusion matrix \n', confusion_matrix(df_result['y3test'], df_result['y3pred']))
# Out:
# Confusion matrix
#  [[56  0]
#  [ 0 77]]

# %%
#all the values are true

# %%
df_result.head()
# Out:
#      y3test  y_pred  y3pred
# 361       1       1       1
# 249       0       0       0
# 271       0       0       0
# 434       1       1       1
# 397       1       1       1

# %% [raw]
# Inference:
#     All the actual values are true ,the given data is significant ,so we fail to reject the actual value.It is more significant in Random forest regressor,Random forest classification models.Random forest model fits good for this data.
